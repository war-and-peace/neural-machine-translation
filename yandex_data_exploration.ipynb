# %%
import os
from exploration_utils import *
# Out:
# [nltk_data] Downloading package stopwords to /home/temur/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Read dataset by Yandex

# %%
source_name = 'Yandex'
corpus_folder_path = 'corpus/'
en_path = os.path.join(corpus_folder_path, 'corpus.en_ru.1m.en')
ru_path = os.path.join(corpus_folder_path, 'corpus.en_ru.1m.ru')

# %%
def read_corpus(corpus_path):
    ''' Loads En/Ru corpus from given path'''
    
    with open(corpus_path, "r") as f:
        return f.readlines()

english = read_corpus(en_path)
russian = read_corpus(ru_path)

# %%
print(f'Total number of sentences: EN: {len(english)}, RU: {len(russian)}')
# Out:
# Total number of sentences: EN: 1000000, RU: 1000000

# %%
en_examples = "\n  ".join(english[3:5])
ru_examples = "\n  ".join(russian[3:5])
print(f'Examples:\nEN:\n  {en_examples}\nRU:\n  {ru_examples}')
# Out:
# Examples:
# EN:
#   Now you have Black Sabbath and Kiss tribute albums.
#
#   I was the one who sat down and copied them.
#
# RU:
#   А сейчас куча триьютов тем же самым BLACK SABBATH и KISS.
#
#   Я был единственным, кто занялся копированием демо на кассете.

# %% [markdown]
# ## Analyzing text statistics

# %%
print_stats(english, language='English')
print_stats(russian, language='Russian')
# Out:
# Stats for English corpus
# 	Total number of tokens: 21252975
# 	Number of unique tokens: 796290
# 	Average number of words per sentence: 21.252975
# 	Most frequent tokens: ['the', 'of', 'and', 'to', 'in', 'a', 'is', 'for', 'that', 'with']
# Stats for Russian corpus
# 	Total number of tokens: 18680351
# 	Number of unique tokens: 1323932
# 	Average number of words per sentence: 18.680351
# 	Most frequent tokens: ['и', 'в', 'на', 'с', 'не', 'что', '-', 'для', 'по', 'к']

# %% [markdown]
# #### Histograms of number of characters per sentence

# %%
number_of_chars_per_sent_hist(english, source_name, language='English')

# %%
number_of_chars_per_sent_hist(russian, source_name, language='Russian')

# %% [markdown]
# #### Histograms of number of words per sentence

# %%
number_of_words_per_sent_hist(english, source_name, language='English')

# %%
number_of_words_per_sent_hist(russian, source_name, language='Russian')

# %% [markdown]
# #### Historgrams of average word length in each sentence

# %%
avg_word_len_per_sent_hist(english, source_name, language='English')
# Out:
# Max avg_word_len: 93.0 Min_avg_word_len 1.2461538461538462

# %% [markdown]
# Let's see a sentence with the maximum average word length:

# %%
print(get_max_avg_word_len_sent(english))
# Out:
# http://www.hds.com/products/storage-systems/adaptable-modular-storage-2000-family/index.html.

# %%
avg_word_len_per_sent_hist(russian, source_name, language='Russian')
# Out:
# Max avg_word_len: 49.666666666666664 Min_avg_word_len 1.6304347826086956

# %%
print(get_max_avg_word_len_sent(russian))
# Out:
# Постоянная ссылка http://www.gotocld.com/ru/central-san-diego-real-estate-market-mid-year-snapshot-of-median-prices-2006-condominiums-and-mtixnjy0.html

# %% [markdown]
# #### Barcharts of the most common stopwords

# %%
most_common_stopwords_bar(english, source_name, language='English')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
most_common_stopwords_bar(russian, source_name, language='Russian')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Barcharts of the most common words (except for stopwords)

# %%
most_common_words_bar(english, source_name, language='English')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
most_common_words_bar(russian, source_name, language='Russian')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Barcharts of the most common n-grams (n=2, n=3)

# %%
most_common_ngrams_bar(english, source_name, language='English')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
most_common_ngrams_bar(russian, source_name, language='Russian')
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
most_common_ngrams_bar(english, source_name, language='English', n=3)
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
most_common_ngrams_bar(russian, source_name, language='Russian', n=3)
# Out:
# /home/temur/anaconda3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Conclusion

# %%
# TODO
